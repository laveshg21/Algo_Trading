# %%
import yfinance as yf

# %%
import pandas as pd

# %%
import numpy as np

# %%
def comb(s):
  Y2=yf.download(s,'2020-10-06','2022-10-06')
  # Y2 = Y2.rename_axis(index='Date', columns="Date")
  W1=yf.download(s,'2022-09-28','2022-10-06')
  # W1=Y2[Y2["Datefinal_W1"] >= '2022-09-13' and Y2["Date"]<='2022-09-20']
  W2=yf.download(s,'2022-09-21','2022-10-06')
  # W2=Y2[Y2["Date"] >= '2022-09-06' and Y2["Date"]<='2022-09-20']
  W4=yf.download(s,'2022-09-07','2022-10-06')
  # W4=Y2[Y2["Datefinal_W1"] >= '2022-08-23' and Y2["Date"]<='2022-09-20']
  W8=yf.download(s,'2022-08-10','2022-10-06')
  # W8=Y2[Y2["Date"] >= '2022-07-06' and Y2["Date"]<='2022-09-20']022-1
  W16=yf.download(s,'2022-06-15','2022-10-06')
  # W16=Y2[Y2["Date"] >= '2022-05-31' and Y2["Date"]<='2022-09-20']
  M6=yf.download(s,'2021-04-06','2022-10-06')
  # M6=Y2[Y2["Date"] >= '2022-03-22' and Y2["Date"]<='2022-09-20']
  Y1=yf.download(s,'2021-10-06','2022-10-06')
  # Y1=Y2[Y2["Date"] >= '2021-09-06' and Y2["Date"]<='2022-09-20']
  # Y2=yf.download(s,'2020-09-20','2022-09-20')022-1

  k=0.35
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord > k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord > k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord > k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord > k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord > k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord > k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord > k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord > k]

  # P035=256*(final_W1.size*100)/(W1.size)+128*(final_W2.size*100)/(W2.size)+64*(final_W4.size*100)/(W4.size)+32*(final_W8.size*100)/(W8.size)+16*(final_W16.size*100)/(W16.size)+8*final_M6+4*(final_Y1.size*100)/(Y1.size)+2*(final_Y2.size*100)/(Y2.size)
  P035=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))

# For k=0.5
  k=0.5
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord > k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord > k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord > k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord > k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord > k]

  low_ch5= pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord > k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord > k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord > k]

  # P05=256*(final_W1.size*100)/(W1.size)+128*(final_W2.size*100)/(W2.size)+64*(final_W4.size*100)/(W4.size)+32*(final_W8.size*100)/(W8.size)+16*(final_W16.size*100)/(W16.size)+8*final_M6+4*(final_Y1.size*100)/(Y1.size)+2*(final_Y2.size*100)/(Y2.size)
  P05=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))


# For k = 1
  k=1
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord > k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord > k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord > k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord > k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord > k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord > k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord > k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord > k]

  # P1=256*(final_W1.size*100)/(W1.size)+128*(final_W2.size*100)/(W2.size)+64*(final_W4.size*100)/(W4.size)+32*(final_W8.size*100)/(W8.size)+16*(final_W16.size*100)/(W16.size)+8*final_M6+4*(final_Y1.size*100)/(Y1.size)+2*(final_Y2.size*100)/(Y2.size)
  P1=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))
# For k=2
  k=2
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord > k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord > k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord > k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord > k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord > k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord > k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord > k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord > k]

  # P2=256*(final_W1.size*100)/(W1.size)+128*(final_W2.size*100)/(W2.size)+64*(final_W4.size*100)/(W4.size)+32*(final_W8.size*100)/(W8.size)+16*(final_W16.size*100)/(W16.size)+8*final_M6+4*(final_Y1.size*100)/(Y1.size)+2*(final_Y2.size*100)/(Y2.size)
  P2=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))

# For k=3.5
  k=3.5
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord > k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord > k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord > k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord > k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord > k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord > k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord > k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord > k]

  # size*100)/(W16.size)+8*final_M6+4*(final_Y1.size*100)/(Y1.size)+2*(final_Y2.size*100)/(Y2.size)
  P35=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))

# Risk
  k=0.5
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord < k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord < k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord < k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord < k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord < k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord < k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord < k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord < k]
  
  R05=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))


  k=1
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord < k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord < k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord < k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord < k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord < k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord < k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord < k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord < k]
  
  R1=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))

# k=0.3
  k=0.3
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord <= k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord <=k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord <= k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord <= k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord <= k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord <= k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord <= k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord <= k]
  
  R03=256*((final_W1.size*100)/(W1.size))+128*((final_W2.size*100)/(W2.size))+64*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))


# For most negative case 
  k=0
  low_ch = pd.DataFrame(columns=['Lord'])
  low_ch['Lord'] = (((W1['Open']-W1['Low'])*100 )/W1['Open'])
  final_W1=low_ch[low_ch.Lord <= k]

  low_ch1 = pd.DataFrame(columns=['Lord'])
  low_ch1['Lord'] = (((W2['Open']-W2['Low'])*100 )/W2['Open'])
  final_W2=low_ch1[low_ch1.Lord <=k]

  low_ch2 = pd.DataFrame(columns=['Lord'])
  low_ch2['Lord'] = (((W4['Open']-W4['Low'])*100 )/W4['Open'])
  final_W4=low_ch2[low_ch2.Lord <= k]

  low_ch3 = pd.DataFrame(columns=['Lord'])
  low_ch3['Lord'] = (((W8['Open']-W8['Low'])*100 )/W8['Open'])
  final_W8=low_ch3[low_ch3.Lord <= k]

  low_ch4 = pd.DataFrame(columns=['Lord'])
  low_ch4['Lord'] = (((W16['Open']-W16['Low'])*100 )/W16['Open'])
  final_W16=low_ch4[low_ch4.Lord <= k]

  low_ch5 = pd.DataFrame(columns=['Lord'])
  low_ch5['Lord'] = (((M6['Open']-M6['Low'])*100 )/M6['Open'])
  final_M6=low_ch5[low_ch5.Lord <= k]

  low_ch6 = pd.DataFrame(columns=['Lord'])
  low_ch6['Lord'] = (((Y1['Open']-Y1['Low'])*100 )/Y1['Open'])
  final_Y1=low_ch6[low_ch6.Lord <= k]

  low_ch7 = pd.DataFrame(columns=['Lord'])
  low_ch7['Lord'] = (((Y2['Open']-Y2['Low'])*100 )/Y2['Open'])
  final_Y2=low_ch7[low_ch7.Lord <= k]
  
  R0=1024*((final_W1.size*100)/(W1.size))+512*((final_W2.size*100)/(W2.size))+256*((final_W4.size*100)/(W4.size))+32*((final_W8.size*100)/(W8.size))+16*((final_W16.size*100)/(W16.size))+8*((final_M6.size*100)/M6.size)+4*((final_Y1.size*100)/(Y1.size))+2*((final_Y2.size*100)/(Y2.size))

  df2 = {'Stock': s, 'P035':P035, 'P05': P05, 'P1': P1, 'P2':P2, 'P35':P35, 'R05':R05, 'R1':R1, 'R03' :R03, 'R0' : R0}
  return df2

# %%
column_names=['Code']
symb=pd.read_csv('harshad.csv',names=['Code'])

# %%
symbols=symb.Code.to_list()

# %%
print(symb.Code.to_list())
# Out:
# ['ABB.NS', 'ACC.NS', 'AUBANK.NS', 'ABBOTINDIA.NS', 'ADANIENT.NS', 'ADANIGREEN.NS', 'ADANIPORTS.NS', 'ATGL.NS', 'ADANITRANS.NS', 'ABCAPITAL.NS', 'ABFRL.NS', 'APLLTD.NS', 'ALKEM.NS', 'AMBUJACEM.NS', 'APOLLOHOSP.NS', 'APOLLOTYRE.NS', 'ASHOKLEY.NS', 'ASIANPAINT.NS', 'ASTRAL.NS', 'AUROPHARMA.NS', 'DMART.NS', 'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJFINANCE.NS', 'BAJAJFINSV.NS', 'BAJAJHLDNG.NS', 'BALKRISIND.NS', 'BANDHANBNK.NS', 'BANKBARODA.NS', 'BANKINDIA.NS', 'BATAINDIA.NS', 'BERGEPAINT.NS', 'BEL.NS', 'BHARATFORG.NS', 'BHEL.NS', 'BPCL.NS', 'BHARTIARTL.NS', 'BIOCON.NS', 'BOSCHLTD.NS', 'BRITANNIA.NS', 'CANBK.NS', 'CHOLAFIN.NS', 'CIPLA.NS', 'CLEAN.NS', 'COALINDIA.NS', 'COFORGE.NS', 'COLPAL.NS', 'CONCOR.NS', 'COROMANDEL.NS', 'CROMPTON.NS', 'CUMMINSIND.NS', 'DLF.NS', 'DABUR.NS', 'DALBHARAT.NS', 'DEEPAKNTR.NS', 'DIVISLAB.NS', 'DIXON.NS', 'LALPATHLAB.NS', 'DRREDDY.NS', 'EICHERMOT.NS', 'EMAMILTD.NS', 'ESCORTS.NS', 'EXIDEIND.NS', 'NYKAA.NS', 'FEDERALBNK.NS', 'FORTIS.NS', 'GAIL.NS', 'GLAND.NS', 'GLENMA
# ...

# %%
finale=pd.DataFrame(columns=['Stock','P035','P05','P1','P2','P35','R05','R1','R03','R0'])

# %%
combine=['ADANITRANS.NS','JSWENERGY.NS','ATGL.NS','BOSCHLTD.NS','ADANIPORTS.NS','APOLLOTYRE.NS','ADANIENT.NS','ADANIGREEN.NS','GODREJPROP.NS','GUJGASLTD.NS','MANAPPURAM.NS','ASHOKLEY.NS','INDIGO.NS','BANDHANBNK.NS','ACC.NS','BHARATFORG.NS','PAYTM.NS','IGL.NS','PGHH.NS','ABB.NS']

# %%
def func(s):
    l=[]
    day1=yf.download(s,'2022-10-06','2022-10-07',interval='1m')
    day2=yf.download(s,'2022-10-07','2022-10-08',interval='1m')
    day3=yf.download(s,'2022-10-10','2022-10-11',interval='1m')
    day4=yf.download(s,'2022-10-11','2022-10-12',interval='1m')
    day5=yf.download(s,'2022-10-12','2022-10-13',interval='1m')
    
    day1=day1.reset_index()
    day1['Only_time']=day1['Datetime'].apply(lambda x:x.time)
    x=day1[day1['Low']==day1['Low'].min()]['Only_time']
    l.append(x.values[0])
    
    day2=day2.reset_index()
    day2['Only_time']=day2['Datetime'].apply(lambda x:x.time)
    x=day2[day2['Low']==day2['Low'].min()]['Only_time']
    l.append(x.values[0])
    
    day3=day3.reset_index()
    day3['Only_time']=day3['Datetime'].apply(lambda x:x.time)
    x=day3[day3['Low']==day3['Low'].min()]['Only_time']
    l.append(x.values[0])
    
    day4=day4.reset_index()
    day4['Only_time']=day4['Datetime'].apply(lambda x:x.time)
    x=day4[day4['Low']==day4['Low'].min()]['Only_time']
    l.append(x.values[0])
    
    day5=day5.reset_index()
    day5['Only_time']=day5['Datetime'].apply(lambda x:x.time)
    x=day5[day5['Low']==day5['Low'].min()]['Only_time']
    l.append(x.values[0])
    
    dict1={
        'Stock':s,
        '2022-10-06':[l[0]],
        '2022-10-07':[l[1]],
        '2022-10-10':[l[2]],
        '2022-10-11':[l[3]],
        '2022-10-12':[l[4]]
    }
    return dict1

# %%
df=pd.DataFrame(columns=['Stock','2022-10-06','2022-10-07','2022-10-10','2022-10-11','2022-10-12'])

# %%
for i in combine:
    print(i)
    x=pd.DataFrame(func(i))
    df=pd.concat([df,x])
# Out:
# ADANITRANS.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ATGL.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df
# Out:
#            Stock 2022-10-06 2022-10-07 2022-10-10 2022-10-11 2022-10-12
# 0  ADANITRANS.NS   09:36:00   14:05:00   15:20:00   13:33:00   12:59:00
# 0   JSWENERGY.NS   09:27:00   09:15:00   09:21:00   15:29:00   10:53:00
# 0        ATGL.NS   09:15:00   13:39:00   09:19:00   09:55:00   09:21:00
# 0    BOSCHLTD.NS   14:34:00   14:31:00   09:56:00   15:29:00   10:58:00
# 0  ADANIPORTS.NS   09:40:00   12:04:00   09:19:00   15:27:00   11:12:00
# 0  APOLLOTYRE.NS   15:29:00   11:23:00   09:19:00   15:01:00   11:12:00
# 0    ADANIENT.NS   09:25:00   12:10:00   14:03:00   09:15:00   13:14:00
# 0  ADANIGREEN.NS   09:18:00   12:01:00   09:15:00   15:15:00   11:22:00
# 0  GODREJPROP.NS   09:15:00   11:01:00   09:20:00   15:20:00   11:18:00
# 0   GUJGASLTD.NS   10:08:00   12:30:00   09:15:00   15:24:00   11:15:00
# 0  MANAPPURAM.NS   09:15:00   09:33:00   10:40:00   15:20:00   09:19:00
# 0    ASHOKLEY.NS   15:20:00   09:17:00   10:13:00   15:20:00   10:59:00
# ...

# %%
df.set_index('Stock',inplace=True)

# %%
#Table showing time at which minimum price was hit
df.head(20)
# Out:
#               2022-10-06 2022-10-07 2022-10-10 2022-10-11 2022-10-12
# Stock
# ADANITRANS.NS   09:36:00   14:05:00   15:20:00   13:33:00   12:59:00
# JSWENERGY.NS    09:27:00   09:15:00   09:21:00   15:29:00   10:53:00
# ATGL.NS         09:15:00   13:39:00   09:19:00   09:55:00   09:21:00
# BOSCHLTD.NS     14:34:00   14:31:00   09:56:00   15:29:00   10:58:00
# ADANIPORTS.NS   09:40:00   12:04:00   09:19:00   15:27:00   11:12:00
# APOLLOTYRE.NS   15:29:00   11:23:00   09:19:00   15:01:00   11:12:00
# ADANIENT.NS     09:25:00   12:10:00   14:03:00   09:15:00   13:14:00
# ADANIGREEN.NS   09:18:00   12:01:00   09:15:00   15:15:00   11:22:00
# GODREJPROP.NS   09:15:00   11:01:00   09:20:00   15:20:00   11:18:00
# GUJGASLTD.NS    10:08:00   12:30:00   09:15:00   15:24:00   11:15:00
# MANAPPURAM.NS   09:15:00   09:33:00   10:40:00   15:20:00   09:19:00
# ASHOKLEY.NS     15:20:00   09:17:00   10:13:00   15:20:00   10:59:00
# ...

# %%
#Now let's find the table for k=.35
df2=pd.DataFrame(columns=['Stock','2022-10-06','2022-10-07','2022-10-10','2022-10-11','2022-10-12'])

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Stock, 2022-10-06, 2022-10-07, 2022-10-10, 2022-10-11, 2022-10-12]
# Index: []

# %%
day11=yf.download('ADANITRANS.NS','2022-10-10','2022-10-11')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
y=(day11['Open'].values[0])*(1-.0035)
y
# Out:
# 3208.73

# %%
min1=yf.download('ADANITRANS.NS','2022-10-10','2022-10-11',interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
min1=min1.reset_index()

# %%
min1['Only_time']=min1['Datetime'].apply(lambda x:x.time)

# %%
l=[]

# %%
min1[(y>=min1['Low'])&(y<=min1['Open'])]['Only_time']
# Out:
# 3      09:18:00
# 5      09:20:00
# 10     09:25:00
# 33     09:48:00
# 34     09:49:00
# 42     09:57:00
# 43     09:58:00
# 297    14:12:00
# 301    14:16:00
# 302    14:17:00
# 304    14:19:00
# 307    14:22:00
# 346    15:01:00
# 347    15:02:00
# 348    15:03:00
# Name: Only_time, dtype: object

# %%
l.append(x)

# %%
l[0]
# Out:
# 7    09:22:00
# 9    09:24:00
# Name: Only_time, dtype: object

# %%
def func2(s):
    l=[]
    day1=yf.download(s,'2022-10-06','2022-10-07',interval='1m')
    day11=yf.download(s,'2022-10-06','2022-10-07')
    day2=yf.download(s,'2022-10-07','2022-10-08',interval='1m')
    day22=yf.download(s,'2022-10-07','2022-10-08')
    day3=yf.download(s,'2022-10-10','2022-10-11',interval='1m')
    day33=yf.download(s,'2022-10-10','2022-10-11')
    day4=yf.download(s,'2022-10-11','2022-10-12',interval='1m')
    day44=yf.download(s,'2022-10-11','2022-10-12')
    day5=yf.download(s,'2022-10-12','2022-10-13',interval='1m')
    day55=yf.download(s,'2022-10-12','2022-10-13')
    
    x1=(day11['Open'].values[0])*(1-.0035)
    x2=(day22['Open'].values[0])*(1-.0035)    
    x3=(day33['Open'].values[0])*(1-.0035)    
    x4=(day44['Open'].values[0])*(1-.0035)    
    x5=(day55['Open'].values[0])*(1-.0035)    
        
    
    day1=day1.reset_index()
    day1['Only_time']=day1['Datetime'].apply(lambda x:x.time)
    x=day1[(x1>day1['Low'])&(x1<day1['High'])]['Only_time']
    l.append(x)
    
    day2=day2.reset_index()
    day2['Only_time']=day2['Datetime'].apply(lambda x:x.time)
    x=day2[(x2>day2['Low'])&(x2<day2['High'])]['Only_time']
    l.append(x)
    
    day3=day3.reset_index()
    day3['Only_time']=day3['Datetime'].apply(lambda x:x.time)
    x=day3[(x3>day3['Low'])&(x3<day3['High'])]['Only_time']
    l.append(x)
    
    day4=day4.reset_index()
    day4['Only_time']=day4['Datetime'].apply(lambda x:x.time)
    x=day4[(x4>day4['Low'])&(x4<day4['High'])]['Only_time']
    l.append(x)
    
    day5=day5.reset_index()
    day5['Only_time']=day5['Datetime'].apply(lambda x:x.time)
    x=day5[(x5>day5['Low'])&(x5<day5['High'])]['Only_time']
    l.append(x)
    
    dict1={
        'Stock':s,
        '2022-10-06':[l[0]],
        '2022-10-07':[l[1]],
        '2022-10-10':[l[2]],
        '2022-10-11':[l[3]],
        '2022-10-12':[l[4]]
    }
    return dict1

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Stock, 2022-10-06, 2022-10-07, 2022-10-10, 2022-10-11, 2022-10-12]
# Index: []

# %%
a=pd.DataFrame(func2('PAYTM.NS'))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
a
# Out:
#       Stock                                         2022-10-06  \
# 0  PAYTM.NS  1    09:16:00
# 2    09:17:00
# 3    09:18:00
# Name...
#
#                                    2022-10-07  \
# 0  Series([], Name: Only_time, dtype: object)
#
#                                      2022-10-10  \
# 0  0    09:15:00
# Name: Only_time, dtype: object
#
#                                           2022-10-11  \
# 0  41     09:56:00
# 111    11:06:00
# 112    11:07:0...
#
#                                           2022-10-12
# 0  5     09:20:00
# 10    09:25:00
# 11    09:26:00
# 2...

# %%
for i in combine:
    print(i)
    a=pd.DataFrame(func2(i))
    df2=pd.concat([df2,a])
# Out:
# ADANITRANS.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df2.set_index('Stock',inplace=True)

# %%
df2.loc['ADANITRANS.NS']['2022-10-07']
# Out:
# 0     09:15:00
# 2     09:17:00
# 6     09:21:00
# 10    09:25:00
# 11    09:26:00
# 12    09:27:00
# 43    09:58:00
# 45    10:00:00
# Name: Only_time, dtype: object

# %%
df2.loc['ADANITRANS.NS']['2022-10-06']
# Out:
# 0      09:15:00
# 1      09:16:00
# 3      09:18:00
# 6      09:21:00
# 33     09:48:00
# 41     09:56:00
# 42     09:57:00
# 43     09:58:00
# 44     09:59:00
# 48     10:03:00
# 50     10:05:00
# 128    11:23:00
# 130    11:25:00
# 134    11:29:00
# 135    11:30:00
# 136    11:31:00
# 137    11:32:00
# 138    11:33:00
# 140    11:35:00
# 142    11:37:00
# 146    11:41:00
# 147    11:42:00
# 317    14:32:00
# 319    14:34:00
# 320    14:35:00
# 323    14:38:00
# 325    14:40:00
# 330    14:45:00
# 331    14:46:00
# 341    14:56:00
# 342    14:57:00
# 365    15:20:00
# 366    15:21:00
# 367    15:22:00
# 369    15:24:00
# 370    15:25:00
# 373    15:28:00
# 374    15:29:00
# Name: Only_time, dtype: object

# %%
df2
# Out:
#                                                       2022-10-06  \
# Stock
# ADANITRANS.NS  0      09:15:00
# 1      09:16:00
# 3      09:18:0...
# JSWENERGY.NS   10    09:25:00
# 12    09:27:00
# 13    09:28:00
# 1...
# ATGL.NS             0    09:15:00
# Name: Only_time, dtype: object
# BOSCHLTD.NS    300    14:31:00
# 301    14:32:00
# 302    14:33:0...
# ADANIPORTS.NS  0      09:15:00
# 1      09:16:00
# 40     09:55:0...
# APOLLOTYRE.NS  1      09:16:00
# 86     10:41:00
# 87     10:42:0...
# ADANIENT.NS    0      09:15:00
# 40     09:55:00
# 43     09:58:0...
# ADANIGREEN.NS         Series([], Name: Only_time, dtype: object)
# GODREJPROP.NS         Series([], Name: Only_time, dtype: object)
# GUJGASLTD.NS   29    09:44:00
# 30    09:45:00
# 31    09:46:00
# 3...
# MANAPPURAM.NS         Series([], Name: Only_time, dtype: object)
# ASHOKLEY.NS    0      09:15:00
# 324    14:39:00
# 329    14:44:0...
# INDIGO.NS      0     09:15:00
# 26    09:41:00
# 30    09:45:00
# 3...
# ...

# %%
#For K=.5
def func2(s):
    l=[]
    day1=yf.download(s,'2022-10-06','2022-10-07',interval='1m')
    day11=yf.download(s,'2022-10-06','2022-10-07')
    day2=yf.download(s,'2022-10-07','2022-10-08',interval='1m')
    day22=yf.download(s,'2022-10-07','2022-10-08')
    day3=yf.download(s,'2022-10-10','2022-10-11',interval='1m')
    day33=yf.download(s,'2022-10-10','2022-10-11')
    day4=yf.download(s,'2022-10-11','2022-10-12',interval='1m')
    day44=yf.download(s,'2022-10-11','2022-10-12')
    day5=yf.download(s,'2022-10-12','2022-10-13',interval='1m')
    day55=yf.download(s,'2022-10-12','2022-10-13')
    
    x1=(day11['Open'].values[0])*(1-.005)
    x2=(day22['Open'].values[0])*(1-.005)    
    x3=(day33['Open'].values[0])*(1-.005)    
    x4=(day44['Open'].values[0])*(1-.005)    
    x5=(day55['Open'].values[0])*(1-.005)    
        
    
    day1=day1.reset_index()
    day1['Only_time']=day1['Datetime'].apply(lambda x:x.time)
    x=day1[(x1>day1['Low'])&(x1<day1['High'])]['Only_time']
    l.append(x)
    
    day2=day2.reset_index()
    day2['Only_time']=day2['Datetime'].apply(lambda x:x.time)
    x=day2[(x2>day2['Low'])&(x2<day2['High'])]['Only_time']
    l.append(x)
    
    day3=day3.reset_index()
    day3['Only_time']=day3['Datetime'].apply(lambda x:x.time)
    x=day3[(x3>day3['Low'])&(x3<day3['High'])]['Only_time']
    l.append(x)
    
    day4=day4.reset_index()
    day4['Only_time']=day4['Datetime'].apply(lambda x:x.time)
    x=day4[(x4>day4['Low'])&(x4<day4['High'])]['Only_time']
    l.append(x)
    
    day5=day5.reset_index()
    day5['Only_time']=day5['Datetime'].apply(lambda x:x.time)
    x=day5[(x5>day5['Low'])&(x5<day5['High'])]['Only_time']
    l.append(x)
    
    dict1={
        'Stock':s,
        '2022-10-06':[l[0]],
        '2022-10-07':[l[1]],
        '2022-10-10':[l[2]],
        '2022-10-11':[l[3]],
        '2022-10-12':[l[4]]
    }
    return dict1

# %%
df3=pd.DataFrame(columns=['Stock','2022-10-06','2022-10-07','2022-10-10','2022-10-11','2022-10-12'])

# %%
for i in combine:
    print(i)
    a=pd.DataFrame(func2(i))
    df3=pd.concat([df3,a])
# Out:
# ADANITRANS.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df3
# Out:
#            Stock                                         2022-10-06  \
# 0  ADANITRANS.NS  0      09:15:00
# 1      09:16:00
# 3      09:18:0...
# 0   JSWENERGY.NS      12    09:27:00
# Name: Only_time, dtype: object
# 0        ATGL.NS         Series([], Name: Only_time, dtype: object)
# 0    BOSCHLTD.NS         Series([], Name: Only_time, dtype: object)
# 0  ADANIPORTS.NS  0      09:15:00
# 1      09:16:00
# 2      09:17:0...
# 0  APOLLOTYRE.NS  96     10:51:00
# 97     10:52:00
# 98     10:53:0...
# 0    ADANIENT.NS  0      09:15:00
# 1      09:16:00
# 33     09:48:0...
# 0  ADANIGREEN.NS         Series([], Name: Only_time, dtype: object)
# 0  GODREJPROP.NS         Series([], Name: Only_time, dtype: object)
# 0   GUJGASLTD.NS  30    09:45:00
# 36    09:51:00
# 37    09:52:00
# 3...
# 0  MANAPPURAM.NS         Series([], Name: Only_time, dtype: object)
# 0    ASHOKLEY.NS  324    14:39:00
# 325    14:40:00
# 326    14:41:0...
# 0      INDIGO.NS  2     09:17:00
# 3     09:18:00
# ...

# %%
#for k=1
def func2(s):
    l=[]
    day1=yf.download(s,'2022-10-06','2022-10-07',interval='1m')
    day11=yf.download(s,'2022-10-06','2022-10-07')
    day2=yf.download(s,'2022-10-07','2022-10-08',interval='1m')
    day22=yf.download(s,'2022-10-07','2022-10-08')
    day3=yf.download(s,'2022-10-10','2022-10-11',interval='1m')
    day33=yf.download(s,'2022-10-10','2022-10-11')
    day4=yf.download(s,'2022-10-11','2022-10-12',interval='1m')
    day44=yf.download(s,'2022-10-11','2022-10-12')
    day5=yf.download(s,'2022-10-12','2022-10-13',interval='1m')
    day55=yf.download(s,'2022-10-12','2022-10-13')
    
    x1=(day11['Open'].values[0])*(1-.01)
    x2=(day22['Open'].values[0])*(1-.01)    
    x3=(day33['Open'].values[0])*(1-.01)    
    x4=(day44['Open'].values[0])*(1-.01)    
    x5=(day55['Open'].values[0])*(1-.01)    
        
    
    day1=day1.reset_index()
    day1['Only_time']=day1['Datetime'].apply(lambda x:x.time)
    x=day1[(x1>day1['Low'])&(x1<day1['High'])]['Only_time']
    l.append(x)
    
    day2=day2.reset_index()
    day2['Only_time']=day2['Datetime'].apply(lambda x:x.time)
    x=day2[(x2>day2['Low'])&(x2<day2['High'])]['Only_time']
    l.append(x)
    
    day3=day3.reset_index()
    day3['Only_time']=day3['Datetime'].apply(lambda x:x.time)
    x=day3[(x3>day3['Low'])&(x3<day3['High'])]['Only_time']
    l.append(x)
    
    day4=day4.reset_index()
    day4['Only_time']=day4['Datetime'].apply(lambda x:x.time)
    x=day4[(x4>day4['Low'])&(x4<day4['High'])]['Only_time']
    l.append(x)
    
    day5=day5.reset_index()
    day5['Only_time']=day5['Datetime'].apply(lambda x:x.time)
    x=day5[(x5>day5['Low'])&(x5<day5['High'])]['Only_time']
    l.append(x)
    
    dict1={
        'Stock':s,
        '2022-10-06':[l[0]],
        '2022-10-07':[l[1]],
        '2022-10-10':[l[2]],
        '2022-10-11':[l[3]],
        '2022-10-12':[l[4]]
    }
    return dict1

# %%
df4=pd.DataFrame(columns=['Stock','2022-10-06','2022-10-07','2022-10-10','2022-10-11','2022-10-12'])

# %%
for i in combine:
    print(i)
    a=pd.DataFrame(func2(i))
    df4=pd.concat([df4,a])
# Out:
# ADANITRANS.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
#For K=2
def func2(s):
    l=[]
    day1=yf.download(s,'2022-10-06','2022-10-07',interval='1m')
    day11=yf.download(s,'2022-10-06','2022-10-07')
    day2=yf.download(s,'2022-10-07','2022-10-08',interval='1m')
    day22=yf.download(s,'2022-10-07','2022-10-08')
    day3=yf.download(s,'2022-10-10','2022-10-11',interval='1m')
    day33=yf.download(s,'2022-10-10','2022-10-11')
    day4=yf.download(s,'2022-10-11','2022-10-12',interval='1m')
    day44=yf.download(s,'2022-10-11','2022-10-12')
    day5=yf.download(s,'2022-10-12','2022-10-13',interval='1m')
    day55=yf.download(s,'2022-10-12','2022-10-13')
    
    x1=(day11['Open'].values[0])*(1-.02)
    x2=(day22['Open'].values[0])*(1-.02)    
    x3=(day33['Open'].values[0])*(1-.02)    
    x4=(day44['Open'].values[0])*(1-.02)    
    x5=(day55['Open'].values[0])*(1-.02)    
        
    
    day1=day1.reset_index()
    day1['Only_time']=day1['Datetime'].apply(lambda x:x.time)
    x=day1[(x1>day1['Low'])&(x1<day1['High'])]['Only_time']
    l.append(x)
    
    day2=day2.reset_index()
    day2['Only_time']=day2['Datetime'].apply(lambda x:x.time)
    x=day2[(x2>day2['Low'])&(x2<day2['High'])]['Only_time']
    l.append(x)
    
    day3=day3.reset_index()
    day3['Only_time']=day3['Datetime'].apply(lambda x:x.time)
    x=day3[(x3>day3['Low'])&(x3<day3['High'])]['Only_time']
    l.append(x)
    
    day4=day4.reset_index()
    day4['Only_time']=day4['Datetime'].apply(lambda x:x.time)
    x=day4[(x4>day4['Low'])&(x4<day4['High'])]['Only_time']
    l.append(x)
    
    day5=day5.reset_index()
    day5['Only_time']=day5['Datetime'].apply(lambda x:x.time)
    x=day5[(x5>day5['Low'])&(x5<day5['High'])]['Only_time']
    l.append(x)
    
    dict1={
        'Stock':s,
        '2022-10-06':[l[0]],
        '2022-10-07':[l[1]],
        '2022-10-10':[l[2]],
        '2022-10-11':[l[3]],
        '2022-10-12':[l[4]]
    }
    return dict1

# %%
df5=pd.DataFrame(columns=['Stock','2022-10-06','2022-10-07','2022-10-10','2022-10-11','2022-10-12'])

# %%
for i in combine:
    print(i)
    a=pd.DataFrame(func2(i))
    df5=pd.concat([df5,a])
# Out:
# ADANITRANS.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
def func2(s):
    l=[]
    day1=yf.download(s,'2022-10-06','2022-10-07',interval='1m')
    day11=yf.download(s,'2022-10-06','2022-10-07')
    day2=yf.download(s,'2022-10-07','2022-10-08',interval='1m')
    day22=yf.download(s,'2022-10-07','2022-10-08')
    day3=yf.download(s,'2022-10-10','2022-10-11',interval='1m')
    day33=yf.download(s,'2022-10-10','2022-10-11')
    day4=yf.download(s,'2022-10-11','2022-10-12',interval='1m')
    day44=yf.download(s,'2022-10-11','2022-10-12')
    day5=yf.download(s,'2022-10-12','2022-10-13',interval='1m')
    day55=yf.download(s,'2022-10-12','2022-10-13')
    
    x1=(day11['Open'].values[0])*(1-.035)
    x2=(day22['Open'].values[0])*(1-.035)    
    x3=(day33['Open'].values[0])*(1-.035)    
    x4=(day44['Open'].values[0])*(1-.035)    
    x5=(day55['Open'].values[0])*(1-.035)    
        
    
    day1=day1.reset_index()
    day1['Only_time']=day1['Datetime'].apply(lambda x:x.time)
    x=day1[(x1>day1['Low'])&(x1<day1['High'])]['Only_time']
    l.append(x)
    
    day2=day2.reset_index()
    day2['Only_time']=day2['Datetime'].apply(lambda x:x.time)
    x=day2[(x2>day2['Low'])&(x2<day2['High'])]['Only_time']
    l.append(x)
    
    day3=day3.reset_index()
    day3['Only_time']=day3['Datetime'].apply(lambda x:x.time)
    x=day3[(x3>day3['Low'])&(x3<day3['High'])]['Only_time']
    l.append(x)
    
    day4=day4.reset_index()
    day4['Only_time']=day4['Datetime'].apply(lambda x:x.time)
    x=day4[(x4>day4['Low'])&(x4<day4['High'])]['Only_time']
    l.append(x)
    
    day5=day5.reset_index()
    day5['Only_time']=day5['Datetime'].apply(lambda x:x.time)
    x=day5[(x5>day5['Low'])&(x5<day5['High'])]['Only_time']
    l.append(x)
    
    dict1={
        'Stock':s,
        '2022-10-06':[l[0]],
        '2022-10-07':[l[1]],
        '2022-10-10':[l[2]],
        '2022-10-11':[l[3]],
        '2022-10-12':[l[4]]
    }
    return dict1

# %%
df6=pd.DataFrame(columns=['Stock','2022-10-06','2022-10-07','2022-10-10','2022-10-11','2022-10-12'])

# %%
for i in combine:
    print(i)
    a=pd.DataFrame(func2(i))
    df6=pd.concat([df6,a])
# Out:
# ADANITRANS.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# JSWENERGY.NS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
df
# Out:
#               2022-10-06 2022-10-07 2022-10-10 2022-10-11 2022-10-12
# Stock
# ADANITRANS.NS   09:36:00   14:05:00   15:20:00   13:33:00   12:59:00
# JSWENERGY.NS    09:27:00   09:15:00   09:21:00   15:29:00   10:53:00
# ATGL.NS         09:15:00   13:39:00   09:19:00   09:55:00   09:21:00
# BOSCHLTD.NS     14:34:00   14:31:00   09:56:00   15:29:00   10:58:00
# ADANIPORTS.NS   09:40:00   12:04:00   09:19:00   15:27:00   11:12:00
# APOLLOTYRE.NS   15:29:00   11:23:00   09:19:00   15:01:00   11:12:00
# ADANIENT.NS     09:25:00   12:10:00   14:03:00   09:15:00   13:14:00
# ADANIGREEN.NS   09:18:00   12:01:00   09:15:00   15:15:00   11:22:00
# GODREJPROP.NS   09:15:00   11:01:00   09:20:00   15:20:00   11:18:00
# GUJGASLTD.NS    10:08:00   12:30:00   09:15:00   15:24:00   11:15:00
# MANAPPURAM.NS   09:15:00   09:33:00   10:40:00   15:20:00   09:19:00
# ASHOKLEY.NS     15:20:00   09:17:00   10:13:00   15:20:00   10:59:00
# ...

# %%
#K=.35
df2
# Out:
#                                                       2022-10-06  \
# Stock
# ADANITRANS.NS  0      09:15:00
# 1      09:16:00
# 3      09:18:0...
# JSWENERGY.NS   10    09:25:00
# 12    09:27:00
# 13    09:28:00
# 1...
# ATGL.NS             0    09:15:00
# Name: Only_time, dtype: object
# BOSCHLTD.NS    300    14:31:00
# 301    14:32:00
# 302    14:33:0...
# ADANIPORTS.NS  0      09:15:00
# 1      09:16:00
# 40     09:55:0...
# APOLLOTYRE.NS  1      09:16:00
# 86     10:41:00
# 87     10:42:0...
# ADANIENT.NS    0      09:15:00
# 40     09:55:00
# 43     09:58:0...
# ADANIGREEN.NS         Series([], Name: Only_time, dtype: object)
# GODREJPROP.NS         Series([], Name: Only_time, dtype: object)
# GUJGASLTD.NS   29    09:44:00
# 30    09:45:00
# 31    09:46:00
# 3...
# MANAPPURAM.NS         Series([], Name: Only_time, dtype: object)
# ASHOKLEY.NS    0      09:15:00
# 324    14:39:00
# 329    14:44:0...
# INDIGO.NS      0     09:15:00
# 26    09:41:00
# 30    09:45:00
# 3...
# ...

# %%
#k=.5
df3
# Out:
#            Stock                                         2022-10-06  \
# 0  ADANITRANS.NS  0      09:15:00
# 1      09:16:00
# 3      09:18:0...
# 0   JSWENERGY.NS      12    09:27:00
# Name: Only_time, dtype: object
# 0        ATGL.NS         Series([], Name: Only_time, dtype: object)
# 0    BOSCHLTD.NS         Series([], Name: Only_time, dtype: object)
# 0  ADANIPORTS.NS  0      09:15:00
# 1      09:16:00
# 2      09:17:0...
# 0  APOLLOTYRE.NS  96     10:51:00
# 97     10:52:00
# 98     10:53:0...
# 0    ADANIENT.NS  0      09:15:00
# 1      09:16:00
# 33     09:48:0...
# 0  ADANIGREEN.NS         Series([], Name: Only_time, dtype: object)
# 0  GODREJPROP.NS         Series([], Name: Only_time, dtype: object)
# 0   GUJGASLTD.NS  30    09:45:00
# 36    09:51:00
# 37    09:52:00
# 3...
# 0  MANAPPURAM.NS         Series([], Name: Only_time, dtype: object)
# 0    ASHOKLEY.NS  324    14:39:00
# 325    14:40:00
# 326    14:41:0...
# 0      INDIGO.NS  2     09:17:00
# 3     09:18:00
# ...

# %%
#K=1
df4
# Out:
#            Stock                                         2022-10-06  \
# 0  ADANITRANS.NS  1      09:16:00
# 4      09:19:00
# 8      09:23:0...
# 0   JSWENERGY.NS         Series([], Name: Only_time, dtype: object)
# 0        ATGL.NS         Series([], Name: Only_time, dtype: object)
# 0    BOSCHLTD.NS         Series([], Name: Only_time, dtype: object)
# 0  ADANIPORTS.NS  10     09:25:00
# 11     09:26:00
# 12     09:27:0...
# 0  APOLLOTYRE.NS         Series([], Name: Only_time, dtype: object)
# 0    ADANIENT.NS  2     09:17:00
# 3     09:18:00
# 4     09:19:00
# 5...
# 0  ADANIGREEN.NS         Series([], Name: Only_time, dtype: object)
# 0  GODREJPROP.NS         Series([], Name: Only_time, dtype: object)
# 0   GUJGASLTD.NS         Series([], Name: Only_time, dtype: object)
# 0  MANAPPURAM.NS         Series([], Name: Only_time, dtype: object)
# 0    ASHOKLEY.NS         Series([], Name: Only_time, dtype: object)
# 0      INDIGO.NS  97     10:52:00
# 98     10:53:00
# ...

# %%
#K=2
df5
# Out:
#            Stock                                         2022-10-06  \
# 0  ADANITRANS.NS         Series([], Name: Only_time, dtype: object)
# 0   JSWENERGY.NS         Series([], Name: Only_time, dtype: object)
# 0        ATGL.NS         Series([], Name: Only_time, dtype: object)
# 0    BOSCHLTD.NS         Series([], Name: Only_time, dtype: object)
# 0  ADANIPORTS.NS         Series([], Name: Only_time, dtype: object)
# 0  APOLLOTYRE.NS         Series([], Name: Only_time, dtype: object)
# 0    ADANIENT.NS         Series([], Name: Only_time, dtype: object)
# 0  ADANIGREEN.NS         Series([], Name: Only_time, dtype: object)
# 0  GODREJPROP.NS         Series([], Name: Only_time, dtype: object)
# 0   GUJGASLTD.NS         Series([], Name: Only_time, dtype: object)
# 0  MANAPPURAM.NS         Series([], Name: Only_time, dtype: object)
# 0    ASHOKLEY.NS         Series([], Name: Only_time, dtype: object)
# 0      INDIGO.NS  201    12:36:00
# 203    12:38:00
# 240    13:15:0...
# ...

# %%
#K=3.5
df6
# Out:
#            Stock                                  2022-10-06  \
# 0  ADANITRANS.NS  Series([], Name: Only_time, dtype: object)
# 0   JSWENERGY.NS  Series([], Name: Only_time, dtype: object)
# 0        ATGL.NS  Series([], Name: Only_time, dtype: object)
# 0    BOSCHLTD.NS  Series([], Name: Only_time, dtype: object)
# 0  ADANIPORTS.NS  Series([], Name: Only_time, dtype: object)
# 0  APOLLOTYRE.NS  Series([], Name: Only_time, dtype: object)
# 0    ADANIENT.NS  Series([], Name: Only_time, dtype: object)
# 0  ADANIGREEN.NS  Series([], Name: Only_time, dtype: object)
# 0  GODREJPROP.NS  Series([], Name: Only_time, dtype: object)
# 0   GUJGASLTD.NS  Series([], Name: Only_time, dtype: object)
# 0  MANAPPURAM.NS  Series([], Name: Only_time, dtype: object)
# 0    ASHOKLEY.NS  Series([], Name: Only_time, dtype: object)
# 0      INDIGO.NS  Series([], Name: Only_time, dtype: object)
# 0  BANDHANBNK.NS  Series([], Name: Only_time, dtype: object)
# ...
